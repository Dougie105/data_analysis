# %% [markdown]
# # Car Prices
# #### Terrell Douglas 12/18/19

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
cars = pd.read_csv('./CarPrice_Assignment.csv')
print(f'Data Shape: {cars.shape}')
# Out:
# Data Shape: (205, 26)

# %% [markdown]
# ### Show the first 5 rows of the data set.

# %%
cars.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ### Show description of the data set

# %%
cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ### Visualize your dataset to demonstrate insights into the data

# %%
sns.lmplot(x='horsepower', y='price', data=cars)
plt.ylim(0, None)
plt.xlim(20, None)

# sns.lmplot(x='fueltype', y='price', data=df, fit_reg=False)
# plt.ylim(0, 5000)
# plt.xlim(20, None)
# Out:
# (20, 302.8325949823038)

# %% [markdown]
# # Verbalize your insights here

# %% [markdown]
# #### Messing with the different factors that affect the price of a vehicle was fascinating. trying different combinations of things was helpful in knowing what seaborn is capable of as well as just seeing how that different data moves around the graph.
#
# #### The cost of a vehicle significantly increases as the horsepower of a vehicle increase. If you swap out horsepower with mpg you can see that the less mpg you have the more expensive your car is going to be. Leading you to see these graphs and come to the conclusion that the vehicles with the most horsepower are terrible on gas and cost a lot of money, most likely because they are the more lux cars

# %% [markdown]
# # More Data

# %%
fish = pd.read_csv('./Fish.csv')
print(f'Data Shape: {fish.shape}')
# Out:
# Data Shape: (159, 7)

# %%
fish.head(5)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
sns.boxplot(x='Species', y='Weight', data=fish)
plt.ylim(-50, None)
plt.xlim(-1, None)
# Out:
# (-1, 6.5)

# %% [markdown]
# # Verbalize more thoughts here

# %% [markdown]
# #### Out og the seven fish in the study, the smelt fish is overall the runt species. The heaviest of the fish are pike and bream.
#
# #### This graph is harder to read I think. I just wanted to use a graph that I was not to firmiliar with and try to figure it out.
